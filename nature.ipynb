# %%
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread('nature.jpg')
img
# Out:
# array([[[56, 68, 80],
#         [57, 69, 81],
#         [56, 69, 83],
#         ...,
#         [ 0,  0,  0],
#         [ 0,  0,  0],
#         [ 3,  3,  3]],
#
#        [[53, 63, 73],
#         [58, 68, 78],
#         [58, 70, 82],
#         ...,
#         [ 2,  2,  2],
#         [ 2,  2,  2],
#         [ 0,  0,  0]],
#
#        [[23, 31, 38],
#         [46, 54, 61],
#         [62, 71, 80],
#         ...,
#         [ 2,  2,  2],
#         [ 0,  0,  0],
#         [ 0,  0,  0]],
#
#        ...,
#
#        [[12, 17, 18],
#         [11, 16, 17],
#         [11, 16, 17],
#         ...,
#         [56, 71, 90],
#         [57, 72, 91],
#         [58, 73, 92]],
#
#        [[11, 16, 17],
#         [13, 18, 19],
#         [14, 19, 20],
#         ...,
#         [56, 71, 90],
#         [57, 71, 90],
#         [58, 72, 91]],
#
#        [[ 9, 14, 15],
#         [11, 16, 17],
#         [13, 18, 19],
#         ...,
#         [56, 71, 90],
#         [56, 70, 89],
#         [56, 70, 89]]], dtype=uint8)

# %%
cv2.imshow('original img',img)

# %%
plt.imshow(img)

# %% [markdown]
# ### Resizing the image

# %%
half = cv2.resize(img, (0, 0), fx = 0.2, fy = 0.2)
bigger = cv2.resize(img, (1050, 1610))

stretch_near = cv2.resize(img, (780, 540), 
                interpolation = cv2.INTER_LINEAR)


Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[img, half, bigger, stretch_near]
count = 4

for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])

plt.show()

# %% [markdown]
# ### RGB to Grayscale

# %%
import cv2
import matplotlib.pyplot as plt

gray_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap='gray')

plt.show()

# %% [markdown]
# ### Normal average method

# %%
import matplotlib.pyplot as plt

(row, col) = img.shape[0:2]

for i in range(row):
    for j in range(col):
        img[i, j] = sum(img[i, j]) * 0.33

plt.imshow(img)
plt.title('Gray Scale image')
# Out:
# Text(0.5, 1.0, 'Gray Scale image')

# %% [markdown]
# ### Weighted average method

# %%
image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

r = image_rgb[:,:,0]
g = image_rgb[:,:,1]
b = image_rgb[:,:,2]


grayscale_image = 0.299 * r + 0.587 * g + 0.114 * b

plt.imshow(grayscale_image, cmap='gray')
plt.show()

# %% [markdown]
# ### Histogram equalization

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = 'nature.jpg'  
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  

# Apply Histogram Equalization
equalized_image = cv2.equalizeHist(image)

# Plot original and equalized images side by side
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Original Image
axs[0].imshow(image, cmap='gray')
axs[0].set_title('Original Image')
axs[0].axis('off')

# Equalized Image
axs[1].imshow(equalized_image, cmap='gray')
axs[1].set_title('Equalized Image')
axs[1].axis('off')


fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].hist(image.ravel(), bins=256, color='green', alpha=0.7)
axs[0].set_title('Histogram of Original Image')

# Histogram for Equalized Image
axs[1].hist(equalized_image.ravel(), bins=256, color='green', alpha=0.7)
axs[1].set_title('Histogram of Equalized Image')

plt.show()
